# %% [markdown]
# ## Decision trees
#
# Decision tree is a very intuitive ways for classification, simply ask questions answered by 'yes' and 'no'. Each queston represents a node of the tree and each node is splited into two branches.

# %% [markdown]
# ### Examples with different max_depth.
# In my own opinion, the decision tree is easy to be overfiting and become very 'ugly', e.g. when the max_depth is set to be too large.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets.samples_generator import make_blobs
plt.style.use('ggplot')

def plot_dt(ax,d,t):
    X, y = make_blobs(n_samples=400, centers=4,
                  random_state=1, cluster_std=1.5)
    
    clf = DecisionTreeClassifier(max_depth=d)
    clf.fit(X, y)

    ax.set_title(t)
    ax.set_xlabel('feature 1', color='gray')
    ax.set_ylabel('feature 2', color='gray')
    ax.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='RdBu', zorder=3)
    
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    # create grid to evaluate model
    x = np.linspace(xlim[0], xlim[1], 500)
    y = np.linspace(ylim[0], ylim[1], 500)
    yy, xx = np.meshgrid(y, x)
    xy = np.vstack([xx.ravel(), yy.ravel()]).T
    zz = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    zz = zz.reshape(xx.shape)
    ax.contourf(xx, yy, zz, cmap='RdBu', alpha=0.3, zorder=1)
    
    
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
plot_dt(ax[0], 4, 'depth=4')
plot_dt(ax[1], 10, 'depth=10')

# %% [markdown]
# ## Random forest
#
# When we have many randomized decision trees, it become a random forest. <br>
# A random forest is able to reduce the effect of overfitting of individual decision tree.

# %%
from sklearn.ensemble import RandomForestClassifier

dtc = DecisionTreeClassifier()
rfc = RandomForestClassifier(n_estimators=100, random_state=50)

def plot_dt(ax, model, t):
    X, y = make_blobs(n_samples=400, centers=4,
                  random_state=1, cluster_std=1.5)
    
    clf = model
    clf.fit(X, y)

    ax.set_title(t)
    ax.set_xlabel('feature 1', color='gray')
    ax.set_ylabel('feature 2', color='gray')
    ax.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='RdBu', zorder=3)
    
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    # create grid to evaluate model
    x = np.linspace(xlim[0], xlim[1], 500)
    y = np.linspace(ylim[0], ylim[1], 500)
    yy, xx = np.meshgrid(y, x)
    xy = np.vstack([xx.ravel(), yy.ravel()]).T
    zz = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    zz = zz.reshape(xx.shape)
    ax.contourf(xx, yy, zz, cmap='RdBu', alpha=0.3, zorder=1)
    
    
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
plot_dt(ax[0], dtc, 'Decision tree')
plot_dt(ax[1], rfc, 'Random Forest')
